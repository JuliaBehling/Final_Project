# %%
# Import Dependencies
import csv
import pandas as pd
import numpy as np
import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-41ec5ca8cd39> in <module>
#       8 import psycopg2
#       9
# ---> 10 from config import db_password
#      11
#      12 import time
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create function/Read CSV file:
def extract_transform_load(data):
    facilities_df = pd.read_csv("Resources/CAL_FIRE_Facilities.csv")
    
    return facilities_df

# %%
data = pd.read_csv(r'Resources/CAL_FIRE_Facilities.csv')
facilities_df = pd.DataFrame(data)

print(facilities_df)
# Out:
#                   X              Y  OBJECTID             NAME    CAD_NAME  \
# 0     256759.612298 -428927.360971         1              541     HIG 541
# 1     261958.958369 -428827.963225         2              542     HIG 542
# 2     254252.194732 -429740.897461         3              543     HIG 543
# 3     273740.896608 -436732.555790         4              551     Yuc 551
# 4     268468.743671 -438277.850908         5              552     Yuc 552
# ...             ...            ...       ...              ...         ...
# 1250   73935.188230 -429155.879117      1251  VCFD Station 53  VNC STA 53
# 1251   88368.308218 -421110.119911      1252  VCFD Station 54  VNC STA 54
# 1252   85767.611410 -418584.171010      1253  VCFD Station 55  VNC STA 55
# 1253   82022.269197 -364407.778137      1254   VCFD Patrol 16     VNC P16
# 1254   86454.176314 -406547.038505      1255  VCFD Station 29  VNC STA 29
#
#                                        AKA  TYPE UNIT          COUNTY  \
# 0                                 Highland   FSA  BDU  San Bernardino
# 1                            East Highland   FSA  BDU  San Bernardino
# 2                                 Sterling   FSA  BDU  San Bernardino
# 3                                  Yucaipa  FSAB  BDU  San Bernardino
# 4                                 Crafton    FSA  BDU  San Bernardino
# ...                                    ...   ...  ...             ...
# 1250                          Port Hueneme  FSCC  VNC         Ventura
# 1251  Camarillo - Battalion 1 Headquarters  FSCC  VNC         Ventura
# 1252                             Las Posas  FSCC  VNC         Ventura
# 1253                             Patrol 16  FSCC  VNC         Ventura
# 1254                           Santa Paula  FSCC  VNC         Ventura
#
#               OWNER FUNDING STAFFING                 ADDRESS          CITY  \
# 0              CITY       A        V          26974 Baseline      Highland
# 1              CITY       A        P          29507 Baseline      Highland
# 2              CITY       A        P       7649 Sterling Ave      Highland
# 3             STATE       C        P         11416 Bryant St       Yucaipa
# 4              CITY       A        P        32664 Yucaipa Bl       Yucaipa
# ...             ...     ...      ...                     ...           ...
# 1250  FIRE DISTRICT       G        P        304 N 2nd Street  Port Hueneme
# 1251  FIRE DISTRICT       G        P     2160 Pickwick Drive     Camarillo
# 1252  FIRE DISTRICT       G        P  403 Valley Vista Drive     Camarillo
# 1253  FIRE DISTRICT       G        P       Chico Larson Road  Frazier Park
# 1254  FIRE DISTRICT       G        P       114 S 10th Street   Santa Paula
#
#         ZIP     PHONE_NUM        LAT         LON
# 0     92346  909-862-3031  34.121425 -117.216078
# 1     92346  909-862-1760  34.120931 -117.159705
# 2     92410  909-884-4100  34.114755 -117.243506
# 3     92399  909-797-1000  34.046457 -117.034721
# 4     92399  909-797-2313  34.034005 -117.092308
# ...     ...           ...        ...         ...
# 1250  93041  805 986-8871  34.150534 -119.198178
# 1251  93010  805 383-6409  34.221843 -119.040776
# 1252  93010  805 383-6414  34.244842 -119.068736
# 1253  93225           NaN  34.733314 -119.103840
# 1254  93060  805 389-9755  34.353260 -119.059986
#
# [1255 rows x 18 columns]

# %%
extract_transform_load(data)
# Out:
#                   X              Y  OBJECTID             NAME    CAD_NAME  \
# 0     256759.612298 -428927.360971         1              541     HIG 541
# 1     261958.958369 -428827.963225         2              542     HIG 542
# 2     254252.194732 -429740.897461         3              543     HIG 543
# 3     273740.896608 -436732.555790         4              551     Yuc 551
# 4     268468.743671 -438277.850908         5              552     Yuc 552
# ...             ...            ...       ...              ...         ...
# 1250   73935.188230 -429155.879117      1251  VCFD Station 53  VNC STA 53
# 1251   88368.308218 -421110.119911      1252  VCFD Station 54  VNC STA 54
# 1252   85767.611410 -418584.171010      1253  VCFD Station 55  VNC STA 55
# 1253   82022.269197 -364407.778137      1254   VCFD Patrol 16     VNC P16
# 1254   86454.176314 -406547.038505      1255  VCFD Station 29  VNC STA 29
#
#                                        AKA  TYPE UNIT          COUNTY  \
# 0                                 Highland   FSA  BDU  San Bernardino
# 1                            East Highland   FSA  BDU  San Bernardino
# 2                                 Sterling   FSA  BDU  San Bernardino
# 3                                  Yucaipa  FSAB  BDU  San Bernardino
# 4                                 Crafton    FSA  BDU  San Bernardino
# ...                                    ...   ...  ...             ...
# 1250                          Port Hueneme  FSCC  VNC         Ventura
# 1251  Camarillo - Battalion 1 Headquarters  FSCC  VNC         Ventura
# 1252                             Las Posas  FSCC  VNC         Ventura
# 1253                             Patrol 16  FSCC  VNC         Ventura
# 1254                           Santa Paula  FSCC  VNC         Ventura
#
#               OWNER FUNDING STAFFING                 ADDRESS          CITY  \
# 0              CITY       A        V          26974 Baseline      Highland
# 1              CITY       A        P          29507 Baseline      Highland
# 2              CITY       A        P       7649 Sterling Ave      Highland
# 3             STATE       C        P         11416 Bryant St       Yucaipa
# 4              CITY       A        P        32664 Yucaipa Bl       Yucaipa
# ...             ...     ...      ...                     ...           ...
# 1250  FIRE DISTRICT       G        P        304 N 2nd Street  Port Hueneme
# 1251  FIRE DISTRICT       G        P     2160 Pickwick Drive     Camarillo
# 1252  FIRE DISTRICT       G        P  403 Valley Vista Drive     Camarillo
# 1253  FIRE DISTRICT       G        P       Chico Larson Road  Frazier Park
# 1254  FIRE DISTRICT       G        P       114 S 10th Street   Santa Paula
#
#         ZIP     PHONE_NUM        LAT         LON
# 0     92346  909-862-3031  34.121425 -117.216078
# 1     92346  909-862-1760  34.120931 -117.159705
# 2     92410  909-884-4100  34.114755 -117.243506
# 3     92399  909-797-1000  34.046457 -117.034721
# 4     92399  909-797-2313  34.034005 -117.092308
# ...     ...           ...        ...         ...
# 1250  93041  805 986-8871  34.150534 -119.198178
# 1251  93010  805 383-6409  34.221843 -119.040776
# 1252  93010  805 383-6414  34.244842 -119.068736
# 1253  93225           NaN  34.733314 -119.103840
# 1254  93060  805 389-9755  34.353260 -119.059986
#
# [1255 rows x 18 columns]

# %%
facilities_df = facilities_df[[ "OBJECTID",
 "NAME",
 "CAD_NAME",
 "AKA",
 "TYPE",
 "UNIT",
 "COUNTY",
 "OWNER",
 "FUNDING",
 "STAFFING",
 "ADDRESS",
 "CITY",
 "ZIP",
 "PHONE_NUM",
 "LAT",
 "LON"]].copy()

facilities_df.head(20)
# Out:
#     OBJECTID                 NAME                 CAD_NAME            AKA  \
# 0          1                  541                  HIG 541       Highland
# 1          2                  542                  HIG 542  East Highland
# 2          3                  543                  HIG 543       Sterling
# 3          4                  551                  Yuc 551        Yucaipa
# 4          5                  552                  Yuc 552       Crafton
# 5          6                  553                  Yuc 553       Wildwood
# 6          7      Pebble Beach FS      BEU Pebble Beach FS            #22
# 7          8      Carmel Hill FFS       BEU Carmel Hill FS            #28
# 8          9          Rio Road FS          BEU Rio Road FS            #25
# 9         10  Carmel Highlands FS  BEU Carmel Highlands FS            #21
# 10        11            Aromas FS            BEU Aromas FS            #35
# 11        12       Upper Ridge FS       BTC Upper Ridge FS     Station 33
# 12        13       South Chico FS       BTC South Chico FS     Station 44
# 13        14            Durham FS            BTC Durham FS     Station 45
# 14        15            Bangor FS            BTC Bangor FS     Station 55
# 15        16           Palermo FS           BTC Palermo FS     Station 72
# 16        17      Kelley Ridge FS      BTC Kelley Ridge FS     Station 64
# 17        18          Richvale FS          BTC Richvale FS     Station 71
# 18        19             Biggs FS             BTC Biggs FS     Station 73
# 19        20           Gridley FS           BTC Gridley FS     Station 74
#
#     TYPE UNIT          COUNTY          OWNER FUNDING STAFFING  \
# 0    FSA  BDU  San Bernardino           CITY       A        V
# 1    FSA  BDU  San Bernardino           CITY       A        P
# 2    FSA  BDU  San Bernardino           CITY       A        P
# 3   FSAB  BDU  San Bernardino          STATE       C        P
# 4    FSA  BDU  San Bernardino           CITY       A        P
# 5    FSA  BDU  San Bernardino           CITY       A        P
# 6    FSA  BEU        Monterey  FIRE DISTRICT       A        P
# 7   FSAB  BEU        Monterey          STATE       C        P
# 8    FSA  BEU        Monterey  FIRE DISTRICT       A        P
# 9    FSA  BEU        Monterey  FIRE DISTRICT       A        P
# 10  FSAB  BEU        Monterey  FIRE DISTRICT       C        P
# 11   FSA  BTC           Butte         COUNTY       A        P
# 12   FSA  BTC           Butte         COUNTY       A        P
# 13   FSA  BTC           Butte         COUNTY       A        C
# 14  FSAB  BTC           Butte         COUNTY       C        C
# 15   FSA  BTC           Butte         COUNTY       A        P
# 16   FSA  BTC           Butte         COUNTY       A        P
# 17   FSA  BTC           Butte         COUNTY       A        C
# 18   FSA  BTC           Butte         COUNTY       A        P
# 19   FSA  BTC           Butte         COUNTY       A        P
#
#                      ADDRESS          CITY         ZIP     PHONE_NUM  \
# 0             26974 Baseline      Highland       92346  909-862-3031
# 1             29507 Baseline      Highland       92346  909-862-1760
# 2          7649 Sterling Ave      Highland       92410  909-884-4100
# 3            11416 Bryant St       Yucaipa       92399  909-797-1000
# 4           32664 Yucaipa Bl       Yucaipa       92399  909-797-2313
# 5   34259 Wildwood Canyon RD       Yucaipa       92399  909-795-3048
# 6      3101-B Forest Lake Rd  Pebble Beach       93953  831-375-4204
# 7         4180 17 Mile Drive  Pebble Beach  93953-9562  831-625-6415
# 8              3775 Rio Road        Carmel  93923-8604  831-624-4511
# 9             73 Fern Cyn Rd        Carmel       93923  831-624-2374
# 10        492 Carpenteria Rd        Aromas  95004-9613  831-726-3130
# 11              14164 Skyway       Magalia       95954  530-872-6323
# 12              2344 Fair St         Chico       95928  530-891-2787
# 13          2367 Campbell St        Durham       95938  530-891-2788
# 14       7540 Oro Bangor Hwy        Bangor       95914  530-679-2411
# 15           2290 Palermo Rd       Palermo       95968  530-538-7565
# 16             22 Walnut Ave      Oroville       95966  530-538-7228
# 17            1236 School St      Richvale       95974  530-882-4304
# 18                  434 B St         Biggs       95917  530-868-5834
# 19        47 East Gridley Rd       Gridley       95948  530-846-5711
#
#           LAT         LON
# 0   34.121425 -117.216078
# 1   34.120931 -117.159705
# 2   34.114755 -117.243506
# 3   34.046457 -117.034721
# 4   34.034005 -117.092308
# 5   34.015635 -117.057167
# 6   36.589174 -121.944537
# 7   36.573822 -121.914047
# 8   36.539613 -121.907278
# 9   36.504613 -121.936341
# 10  36.879496 -121.640959
# 11  39.819512 -121.592138
# 12  39.717011 -121.816178
# 13  39.643660 -121.800245
# 14  39.390392 -121.408712
# 15  39.435599 -121.545565
# 16  39.513572 -121.486378
# 17  39.495163 -121.747168
# 18  39.413842 -121.709044
# 19  39.363489 -121.685815

# %%
facilities_df.count()
# Out:
# OBJECTID     1255
# NAME         1255
# CAD_NAME     1255
# AKA           785
# TYPE         1254
# UNIT         1220
# COUNTY       1243
# OWNER        1227
# FUNDING      1211
# STAFFING     1201
# ADDRESS      1255
# CITY         1255
# ZIP          1177
# PHONE_NUM    1111
# LAT          1255
# LON          1255
# dtype: int64

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fires_data"
engine = create_engine(db_string)
facilities_df.to_sql(name='facilities_data', con=engine, if_exists='replace', index=False)

# create a variable for the number of rows imported
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(f'Resources/CAL_FIRE_Facilities.csv', chunksize=100):
    
    # print out the range of rows that are being imported
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    
    # increment the number of rows imported by the size of 'data'
    rows_imported += len(data)
    
    # print that the rows have finished importing
    print(f'Done. {time.time() - start_time} total seconds elapsed')
    
#return facilities_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-82de31981380> in <module>
# ----> 1 db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fires_data"
#       2 engine = create_engine(db_string)
#       3 facilities_df.to_sql(name='facilities_data', con=engine, if_exists='replace', index=False)
#       4
#       5 # create a variable for the number of rows imported
#
# NameError: name 'db_password' is not defined
